# %%
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import scipy.spatial
import functools

# %matplotlib inline

# %%
### Kernel function generators
def linear_kernel(X1, X2):
    """
    Computes the linear kernel between two sets of vectors.
    Args:
        X1 - an n1xd matrix with vectors x1_1,...,x1_n1 in the rows
        X2 - an n2xd matrix with vectors x2_1,...,x2_n2 in the rows
    Returns:
        matrix of size n1xn2, with x1_i^T x2_j in position i,j
    """
    return np.dot(X1,np.transpose(X2))
 
def RBF_kernel(X1,X2,sigma):
    """
    Computes the RBF kernel between two sets of vectors   
    Args:
        X1 - an n1xd matrix with vectors x1_1,...,x1_n1 in the rows
        X2 - an n2xd matrix with vectors x2_1,...,x2_n2 in the rows
        sigma - the bandwidth (i.e. standard deviation) for the RBF/Gaussian kernel
    Returns:
        matrix of size n1xn2, with exp(-||x1_i-x2_j||^2/(2 sigma^2)) in position i,j
    """
    #TODO
    return np.exp(-scipy.spatial.distance.cdist(X1,X2,'sqeuclidean')/(2.*sigma**2.))

def polynomial_kernel(X1, X2, offset, degree):
    """
    Computes the inhomogeneous polynomial kernel between two sets of vectors
    Args:
        X1 - an n1xd matrix with vectors x1_1,...,x1_n1 in the rows
        X2 - an n2xd matrix with vectors x2_1,...,x2_n2 in the rows
        offset, degree - two parameters for the kernel
    Returns:
        matrix of size n1xn2, with (offset + <x1_i,x2_j>)^degree in position i,j
    """
    #TODO
    return (offset + linear_kernel(X1,X2))**degree

# %%
# PLot kernel machine functions

plot_step = .01
xpts = np.arange(-6.0, 6, plot_step).reshape(-1,1)
prototypes = np.array([-4,-1,0,2]).reshape(-1,1)

# Linear kernel
y = linear_kernel(prototypes, xpts) 
print (xpts.shape)
print (prototypes.shape)
print (y.shape)
for i in range(len(prototypes)):
    label = "Linear@"+str(prototypes[i,:])
    plt.plot(xpts, y[i,:], label=label)
plt.legend(loc = 'best')
plt.show()
# Out:
# (1200, 1)
# (4, 1)
# (4, 1200)

# %%
# PLot kernel machine functions

plot_step = .01
xpts = np.arange(-6.0, 6, plot_step).reshape(-1,1)
prototypes = np.array([-4,-1,0,2]).reshape(-1,1)

# RBF kernel
y = RBF_kernel(prototypes, xpts,1) 
for i in range(len(prototypes)):
    label = "RBF@"+str(prototypes[i,:])
    plt.plot(xpts, y[i,:], label=label)
plt.legend(loc = 'best')
plt.show()

# %%
# PLot kernel machine functions

plot_step = .01
xpts = np.arange(-6.0, 6, plot_step).reshape(-1,1)
prototypes = np.array([-4,-1,0,2]).reshape(-1,1)

# Linear kernel
y = polynomial_kernel(prototypes, xpts,1,3) 
for i in range(len(prototypes)):
    label = "Polynomial@"+str(prototypes[i,:])
    plt.plot(xpts, y[i,:], label=label)
plt.legend(loc = 'best')
plt.show()

# %%
class Kernel_Machine(object):
    def __init__(self, kernel, prototype_points, weights):
        """
        Args:
            kernel(X1,X2) - a function return the cross-kernel matrix between rows of X1 and rows of X2 for kernel k
            prototype_points - an Rxd matrix with rows mu_1,...,mu_R
            weights - a vector of length R with entries w_1,...,w_R
        """

        self.kernel = kernel
        self.prototype_points = prototype_points
        self.weights = weights
        
    def predict(self, X):
        """
        Evaluates the kernel machine on the points given by the rows of X
        Args:
            X - an nxd matrix with inputs x_1,...,x_n in the rows
        Returns:
            Vector of kernel machine evaluations on the n points in X.  Specifically, jth entry of return vector is
                Sum_{i=1}^R w_i k(x_j, mu_i)
        """
        # TODO
        return self.kernel(X,self.prototype_points).dot(self.weights)

# %%
k = functools.partial(RBF_kernel, sigma = 1)
prototypes = np.array([-1,0,1]).reshape(-1,1)
weights = np.array([1,-1,1]).reshape(-1,1)
machine = Kernel_Machine(k, prototypes, weights)
xpts = np.arange(-6.0, 6, plot_step).reshape(-1,1)
preds = machine.predict(xpts)
plt.plot(xpts,preds)
plt.show()

# %% [markdown]
# Load train & test data; Convert to column vectors so it generalizes well to data in higher dimensions.

# %%
data_train,data_test = np.loadtxt("krr-train.txt"),np.loadtxt("krr-test.txt")
x_train, y_train = data_train[:,0].reshape(-1,1),data_train[:,1].reshape(-1,1)
x_test, y_test = data_test[:,0].reshape(-1,1),data_test[:,1].reshape(-1,1)

# %%
plt.plot(x_train,y_train,'o')
plt.show()

# %%
def train_kernel_ridge_regression(X, y, kernel, l2reg):
    # TODO
    K = kernel(X,X)
    tmp = K.copy()
    tmp[np.diag_indices_from(K)] += l2reg
    alpha = np.linalg.inv(tmp).dot(y)
    return Kernel_Machine(kernel, X, alpha)

# %%
plot_step = .001
xpts = np.arange(0 , 1, plot_step).reshape(-1,1)
plt.plot(x_train,y_train,'o')
l2reg = 0.0001
for sigma in [.01,.1,1]:
    k = functools.partial(RBF_kernel, sigma=sigma)
    f = train_kernel_ridge_regression(x_train, y_train, k, l2reg=l2reg)
    label = "Sigma="+str(sigma)+",L2Reg="+str(l2reg)
    plt.plot(xpts, f.predict(xpts), label=label)
plt.legend(loc = 'best')
plt.ylim(-1,1.5)
plt.show()

# %%
plot_step = .001
xpts = np.arange(0 , 1, plot_step).reshape(-1,1)
plt.plot(x_train,y_train,'o')
sigma= .02
for l2reg in [.0001,.01,.1,2]:
    k = functools.partial(RBF_kernel, sigma=sigma)
    f = train_kernel_ridge_regression(x_train, y_train, k, l2reg=l2reg)
    label = "Sigma="+str(sigma)+",L2Reg="+str(l2reg)
    plt.plot(xpts, f.predict(xpts), label=label)
plt.legend(loc = 'best')
plt.ylim(-1,1.5)
plt.show()

# %%
from sklearn.base import BaseEstimator, RegressorMixin, ClassifierMixin

class KernelRidgeRegression(BaseEstimator, RegressorMixin):  
    """sklearn wrapper for our kernel ridge regression"""
     
    def __init__(self, kernel="RBF", sigma=1, degree=2, offset=1, l2reg=1):        
        self.kernel = kernel
        self.sigma = sigma
        self.degree = degree
        self.offset = offset
        self.l2reg = l2reg 

    def fit(self, X, y=None):
        """
        This should fit classifier. All the "work" should be done here.
        """
        if (self.kernel == "linear"):
            self.k = linear_kernel
        elif (self.kernel == "RBF"):
            self.k = functools.partial(RBF_kernel, sigma=self.sigma)
        elif (self.kernel == "polynomial"):
            self.k = functools.partial(polynomial_kernel, offset=self.offset, degree=self.degree)
        else:
            raise ValueError('Unrecognized kernel type requested.')
        
        self.kernel_machine_ = train_kernel_ridge_regression(X, y, self.k, self.l2reg)

        return self

    def predict(self, X, y=None):
        try:
            getattr(self, "kernel_machine_")
        except AttributeError:
            raise RuntimeError("You must train classifer before predicting data!")

        return(self.kernel_machine_.predict(X))

    def score(self, X, y=None):
        # get the average square error
        return(((self.predict(X)-y)**2).mean())

# %%
from sklearn.model_selection import GridSearchCV,PredefinedSplit
from sklearn.model_selection import ParameterGrid
from sklearn.metrics import mean_squared_error,make_scorer
import pandas as pd
    
test_fold = [-1]*len(x_train) + [0]*len(x_test)   #0 corresponds to test, -1 to train
predefined_split = PredefinedSplit(test_fold=test_fold)

# %%
param_grid = [{'kernel': ['RBF'],'sigma':[0.01,0.03,.1,.3,1,3,10,30], 'l2reg': np.exp2(-np.arange(-5,5,1))},
              {'kernel':['polynomial'],'offset':np.arange(-3,3,0.5), 'degree':[2,3,4,5],'l2reg':np.exp2(-np.arange(-5,5,1)) },
              {'kernel':['linear'],'l2reg': [10,1,.01]}]
kernel_ridge_regression_estimator = KernelRidgeRegression()
grid = GridSearchCV(kernel_ridge_regression_estimator, 
                    param_grid,
                    cv = predefined_split,
                    scoring = make_scorer(mean_squared_error,greater_is_better = False),
#                     n_jobs = -1  #should allow parallelism, but crashes Python on my machine
                   )
grid.fit(np.vstack((x_train,x_test)),np.vstack((y_train,y_test)))
# Out:
# GridSearchCV(cv=PredefinedSplit(test_fold=array([-1, -1, ...,  0,  0])),
#              error_score=nan,
#              estimator=KernelRidgeRegression(degree=2, kernel='RBF', l2reg=1,
#                                              offset=1, sigma=1),
#              iid='deprecated', n_jobs=None,
#              param_grid=[{'kernel': ['RBF'],
#                           'l2reg': array([32.    , 16.    ,  8.    ,  4.    ,  2.    ,  1.    ,  0.5   ,
#         0.25  ,  0.125 ,  0.0625]),
#                           'sigma': [0.01, 0.03, 0.1, 0.3, 1, 3, 10, 30]},
#                          {'degree': [2, 3, 4, 5], 'kernel': ['polynomial'],
#                           'l2reg': array([32.    , 16.    ,  8.    ,  4.    ,  2.    ,  1.    ,  0.5   ,
#         0.25  ,  0.125 ,  0.0625]),
#                           'offset': array([-3. , -2.5, -2. , -1.5, -1. , -0.5,  0. ,  0.5,  1. ,  1.5,  2. ,
#         2.5])},
#                          {'kernel': ['linear'], 'l2reg': [10, 1, 0.01]}],
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=make_scorer(mean_squared_error, greater_is_better=False),
#              verbose=0)

# %%
pd.set_option('display.max_rows', 600)
df = pd.DataFrame(grid.cv_results_)
# Flip sign of score back, because GridSearchCV likes to maximize,
# so it flips the sign of the score if "greater_is_better=FALSE"
df['mean_test_score'] = -df['mean_test_score']
# df['mean_train_score'] = -df['mean_train_score']
cols_to_keep = ["param_kernel","param_l2reg" ,"param_offset","param_degree",
                "param_sigma","mean_test_score"]
df_toshow = df[cols_to_keep].fillna('-')
df_toshow.sort_values(by=["mean_test_score"])
# Out:
#     param_kernel  param_l2reg param_offset param_degree param_sigma  \
# 49           RBF       0.5000            -            -        0.03
# 57           RBF       0.2500            -            -        0.03
# 41           RBF       1.0000            -            -        0.03
# 65           RBF       0.1250            -            -        0.03
# 72           RBF       0.0625            -            -        0.01
# 64           RBF       0.1250            -            -        0.01
# 73           RBF       0.0625            -            -        0.03
# 56           RBF       0.2500            -            -        0.01
# 74           RBF       0.0625            -            -         0.1
# 33           RBF       2.0000            -            -        0.03
# 66           RBF       0.1250            -            -         0.1
# 48           RBF       0.5000            -            -        0.01
# 58           RBF       0.2500            -            -         0.1
# 50           RBF       0.5000            -            -         0.1
# 42           RBF       1.0000            -            -         0.1
# 34           RBF       2.0000            -            -         0.1
# 67           RBF       0.1250            -            -         0.3
# 59           RBF       0.2500            -            -         0.3
# 26           RBF       4.0000            -            -         0.1
# 75           RBF       0.0625            -            -         0.3
# 51           RBF       0.5000            -            -         0.3
# 40           RBF       1.0000            -            -        0.01
# 43           RBF       1.0000            -            -         0.3
# 25           RBF       4.0000            -            -        0.03
# 18           RBF       8.0000            -            -         0.1
# 35           RBF       2.0000            -            -         0.3
# 27           RBF       4.0000            -            -         0.3
# 559   polynomial       0.0625          2.5            5           -
# 32           RBF       2.0000            -            -        0.01
# 558   polynomial       0.0625            2            5           -
# 557   polynomial       0.0625          1.5            5           -
# 10           RBF      16.0000            -            -         0.1
# 547   polynomial       0.1250          2.5            5           -
# 17           RBF       8.0000            -            -        0.03
# 546   polynomial       0.1250            2            5           -
# 556   polynomial       0.0625            1            5           -
# 545   polynomial       0.1250          1.5            5           -
# 535   polynomial       0.2500          2.5            5           -
# 19           RBF       8.0000            -            -         0.3
# 534   polynomial       0.2500            2            5           -
# 544   polynomial       0.1250            1            5           -
# 76           RBF       0.0625            -            -           1
# 533   polynomial       0.2500          1.5            5           -
# 523   polynomial       0.5000          2.5            5           -
# 528   polynomial       0.2500           -1            5           -
# 522   polynomial       0.5000            2            5           -
# 180   polynomial       0.1250           -1            2           -
# 188   polynomial       0.0625           -3            2           -
# 169   polynomial       0.2500         -0.5            2           -
# 189   polynomial       0.0625         -2.5            2           -
# 190   polynomial       0.0625           -2            2           -
# 191   polynomial       0.0625         -1.5            2           -
# 199   polynomial       0.0625          2.5            2           -
# 198   polynomial       0.0625            2            2           -
# 179   polynomial       0.1250         -1.5            2           -
# 197   polynomial       0.0625          1.5            2           -
# 192   polynomial       0.0625           -1            2           -
# 178   polynomial       0.1250           -2            2           -
# 196   polynomial       0.0625            1            2           -
# 181   polynomial       0.1250         -0.5            2           -
# 177   polynomial       0.1250         -2.5            2           -
# 176   polynomial       0.1250           -3            2           -
# 283   polynomial       0.5000          2.5            3           -
# 511   polynomial       1.0000          2.5            5           -
# 521   polynomial       0.5000          1.5            5           -
# 439   polynomial       0.0625          2.5            4           -
# 193   polynomial       0.0625         -0.5            2           -
# 282   polynomial       0.5000            2            3           -
# 294   polynomial       0.2500            2            3           -
# 532   polynomial       0.2500            1            5           -
# 438   polynomial       0.0625            2            4           -
# 295   polynomial       0.2500          2.5            3           -
# 293   polynomial       0.2500          1.5            3           -
# 157   polynomial       0.5000         -0.5            2           -
# 437   polynomial       0.0625          1.5            4           -
# 195   polynomial       0.0625          0.5            2           -
# 356   polynomial       4.0000           -3            4           -
# 510   polynomial       1.0000            2            5           -
# 313   polynomial       0.0625         -0.5            3           -
# 69           RBF       0.1250            -            -           3
# 446   polynomial      32.0000            0            5           -
# 110   polynomial       8.0000            0            2           -
# 206   polynomial      32.0000            0            3           -
# 91    polynomial      32.0000          2.5            2           -
# 90    polynomial      32.0000            2            2           -
# 20           RBF       8.0000            -            -           1
# 89    polynomial      32.0000          1.5            2           -
# 61           RBF       0.2500            -            -           3
# 98    polynomial      16.0000            0            2           -
# 88    polynomial      32.0000            1            2           -
# 517   polynomial       0.5000         -0.5            5           -
# 108   polynomial       8.0000           -1            2           -
# 53           RBF       0.5000            -            -           3
# 92    polynomial      16.0000           -3            2           -
# 87    polynomial      32.0000          0.5            2           -
# 324   polynomial      32.0000           -1            4           -
# 248   polynomial       2.0000           -3            3           -
# 85    polynomial      32.0000         -0.5            2           -
# 336   polynomial      16.0000           -1            4           -
# 86    polynomial      32.0000            0            2           -
# 78           RBF       0.0625            -            -          10
# 45           RBF       1.0000            -            -           3
# 12           RBF      16.0000            -            -           1
# 93    polynomial      16.0000         -2.5            2           -
# 70           RBF       0.1250            -            -          10
# 37           RBF       2.0000            -            -           3
# 505   polynomial       1.0000         -0.5            5           -
# 4            RBF      32.0000            -            -           1
# 62           RBF       0.2500            -            -          10
# 493   polynomial       2.0000         -0.5            5           -
# 241   polynomial       4.0000         -0.5            3           -
# 29           RBF       4.0000            -            -           3
# 561       linear       1.0000            -            -           -
# 562       linear       0.0100            -            -           -
# 560       linear      10.0000            -            -           -
# 54           RBF       0.5000            -            -          10
# 229   polynomial       8.0000         -0.5            3           -
# 79           RBF       0.0625            -            -          30
# 253   polynomial       2.0000         -0.5            3           -
# 481   polynomial       4.0000         -0.5            5           -
# 361   polynomial       4.0000         -0.5            4           -
# 21           RBF       8.0000            -            -           3
# 349   polynomial       8.0000         -0.5            4           -
# 46           RBF       1.0000            -            -          10
# 217   polynomial      16.0000         -0.5            3           -
# 71           RBF       0.1250            -            -          30
# 469   polynomial       8.0000         -0.5            5           -
# 13           RBF      16.0000            -            -           3
# 84    polynomial      32.0000           -1            2           -
# 337   polynomial      16.0000         -0.5            4           -
# 38           RBF       2.0000            -            -          10
# 205   polynomial      32.0000         -0.5            3           -
# 63           RBF       0.2500            -            -          30
# 457   polynomial      16.0000         -0.5            5           -
# 5            RBF      32.0000            -            -           3
# 325   polynomial      32.0000         -0.5            4           -
# 30           RBF       4.0000            -            -          10
# 55           RBF       0.5000            -            -          30
# 445   polynomial      32.0000         -0.5            5           -
# 22           RBF       8.0000            -            -          10
# 47           RBF       1.0000            -            -          30
# 14           RBF      16.0000            -            -          10
# 94    polynomial      16.0000           -2            2           -
# 39           RBF       2.0000            -            -          30
# 6            RBF      32.0000            -            -          10
# 31           RBF       4.0000            -            -          30
# 7            RBF      32.0000            -            -          30
# 23           RBF       8.0000            -            -          30
# 15           RBF      16.0000            -            -          30
# 550   polynomial       0.0625           -2            5           -
# 373   polynomial       2.0000         -0.5            4           -
# 529   polynomial       0.2500         -0.5            5           -
# 204   polynomial      32.0000           -1            3           -
# 156         0.073883
# 452         0.073891
# 473         0.073958
# 423         0.074025
# 175         0.074084
# 288         0.074541
# 174         0.074654
# 417         0.074781
# 365         0.075212
# 543         0.075395
# 512         0.075548
# 173         0.075609
# 274         0.075684
# 496         0.075687
# 491         0.075749
# 354         0.076239
# 301         0.076374
# 332         0.076423
# 371         0.076579
# 24          0.076673
# 411         0.076842
# 155         0.077379
# 258         0.077449
# 172         0.077521
# 376         0.077986
# 383         0.078052
# 526         0.078090
# 450         0.078392
# 268         0.079092
# 154         0.079133
# 343         0.080143
# 153         0.080175
# 152         0.080864
# 275         0.080913
# 484         0.081032
# 346         0.081303
# 461         0.081440
# 531         0.081538
# 418         0.081664
# 2           0.081715
# 399         0.081792
# 279         0.082031
# 525         0.082331
# 171         0.083047
# 260         0.083305
# 257         0.083518
# 359         0.083721
# 60          0.084526
# 333         0.084578
# 11          0.085113
# 539         0.085398
# 524         0.085978
# 519         0.086460
# 353         0.086739
# 247         0.086769
# 453         0.087017
# 9           0.087575
# 466         0.087931
# 163         0.087934
# 553         0.088254
# 552         0.088616
# 144         0.088745
# 162         0.088812
# 432         0.089048
# 364         0.089095
# 342         0.089409
# 387         0.089595
# 472         0.089937
# 261         0.090043
# 161         0.090224
# 507         0.091372
# 320         0.091795
# 246         0.092463
# 160         0.092860
# 440         0.093058
# 256         0.093525
# 449         0.093619
# 143         0.094184
# 267         0.094961
# 331         0.095595
# 538         0.096293
# 142         0.096601
# 404         0.097031
# 495         0.097467
# 141         0.097956
# 334         0.098205
# 133         0.098360
# 384         0.098548
# 276         0.098792
# 140         0.098821
# 375         0.099207
# 347         0.099270
# 159         0.099342
# 395         0.099732
# 245         0.100007
# 394         0.100869
# 460         0.100907
# 341         0.102065
# 372         0.102085
# 352         0.102735
# 321         0.103515
# 262         0.103728
# 52          0.104339
# 479         0.104417
# 235         0.104556
# 16          0.105149
# 483         0.105729
# 330         0.105908
# 537         0.106065
# 151         0.106525
# 504         0.107254
# 150         0.107354
# 255         0.108321
# 149         0.108636
# 419         0.108748
# 244         0.109559
# 132         0.109794
# 363         0.109798
# 234         0.110210
# 148         0.110873
# 3           0.111000
# 448         0.112060
# 131         0.115126
# 340         0.115506
# 147         0.115622
# 471         0.115763
# 360         0.115976
# 1           0.116212
# 536         0.116502
# 233         0.116532
# 329         0.116600
# 130         0.117190
# 393         0.117915
# 129         0.118272
# 128         0.118936
# 396         0.119069
# 322         0.119141
# 335         0.119505
# 243         0.120229
# 351         0.120974
# 223         0.121427
# 232         0.123079
# 44          0.123539
# 139         0.123999
# 138         0.124457
# 137         0.125137
# 222         0.125423
# 459         0.125495
# 506         0.126197
# 136         0.126239
# 518         0.126462
# 494         0.126609
# 328         0.126613
# 530         0.126772
# 542         0.126983
# 554         0.127104
# 135         0.128362
# 482         0.129110
# 8           0.129333
# 221         0.129392
# 551         0.130113
# 386         0.130311
# 398         0.130476
# 374         0.130541
# 410         0.130658
# 422         0.130778
# 434         0.130846
# 231         0.130945
# 227         0.286239
# 548         0.300208
# 443         0.323140
# 226         0.361123
# 408         0.367961
# 240         0.371295
# 264         0.388738
# 121         0.450374
# 250         0.458374
# 433         0.463177
# 420         0.477215
# 225         0.477817
# 467         0.510847
# 385         0.514765
# 81          0.547708
# 406         0.591872
# 277         0.656594
# 224         0.676627
# 492         0.755375
# 239         0.810866
# 480         0.837867
# 82          1.193037
# 455         1.728481
# 251         2.639308
# 238         2.830600
# 407         2.973503
# 252         3.411587
# 236         5.483484
# 541        22.237509
# 237       176.827125
# 442      1491.735671

# %%
## Plot the best polynomial and RBF fits you found
plot_step = .01
xpts = np.arange(-.5 , 1.5, plot_step).reshape(-1,1)
plt.plot(x_train,y_train,'o')
plt.plot(x_test,y_test,'o')
#Plot best polynomial fit
offset= 2.5
degree = 5
l2reg = 0.0625
k = functools.partial(polynomial_kernel, offset=offset, degree=degree)
f = train_kernel_ridge_regression(x_train, y_train, k, l2reg=l2reg)
label = "Offset="+str(offset)+",Degree="+str(degree)+",L2Reg="+str(l2reg)
plt.plot(xpts, f.predict(xpts), label=label)
#Plot best RBF fit
sigma = 0.03
l2reg= 0.5
k = functools.partial(RBF_kernel, sigma=sigma)
f = train_kernel_ridge_regression(x_train, y_train, k, l2reg=l2reg)
label = "Sigma="+str(sigma)+",L2Reg="+str(l2reg)
plt.plot(xpts, f.predict(xpts), label=label)
plt.legend(loc = 'best')
plt.ylim(-1,1.75)
plt.show()

# %%
# Load and plot the SVM data
#load the training and test sets
data_train,data_test = np.loadtxt("svm-train.txt"),np.loadtxt("svm-test.txt")
x_train, y_train = data_train[:,0:2], data_train[:,2].reshape(-1,1)
x_test, y_test = data_test[:,0:2], data_test[:,2].reshape(-1,1)

#determine predictions for the training set
yplus = np.ma.masked_where(y_train[:,0]<=0, y_train[:,0])
xplus = x_train[~np.array(yplus.mask)]
yminus = np.ma.masked_where(y_train[:,0]>0, y_train[:,0])
xminus = x_train[~np.array(yminus.mask)]

#plot the predictions for the training set
figsize = plt.figaspect(1)
f, (ax) = plt.subplots(1, 1, figsize=figsize) 

pluses = ax.scatter (xplus[:,0], xplus[:,1], marker='+', c='r', label = '+1 labels for training set')
minuses = ax.scatter (xminus[:,0], xminus[:,1], marker=r'$-$', c='b', label = '-1 labels for training set')

ax.set_ylabel(r"$x_2$", fontsize=11)
ax.set_xlabel(r"$x_1$", fontsize=11)
ax.set_title('Training set size = %s'% len(data_train), fontsize=9)  
ax.axis('tight')
ax.legend(handles=[pluses, minuses], fontsize=9)
plt.show()

# %%
def kernelized_pegasos(K,y,l2reg,max_epoch):
    """
    K: nxn kernel matrix
    y: nx1 labels
    l2reg : regularization parameter
    """
    n = K.shape[0]
    alpha_ = np.zeros(n)
    t = 0
    while t <= max_epoch:
        t += 1
        eta_ = 1/(t*l2reg)
        j = np.random.choice(range(n))
        alpha_ *= (1-1/t)
        if y[j]*K[j].dot(alpha_) < 1:                
            alpha_[j] += eta_*y[j]
    return alpha_

# %%
def train_soft_svm(X,y,kernel,max_epoch,l2reg):
    K = kernel(X,X)
    alpha = kernelized_pegasos(K,y,l2reg,max_epoch)
    return Kernel_Machine(kernel, X, alpha)

# %%
class KernelSVM(BaseEstimator, RegressorMixin):  
    """sklearn wrapper for our kernel ridge regression"""
     
    def __init__(self, kernel="RBF", sigma=1, degree=2, offset=1, max_epoch=5000, l2reg=1):        
        self.kernel = kernel
        self.sigma = sigma
        self.degree = degree
        self.offset = offset
        self.l2reg = l2reg 
        self.max_epoch = max_epoch

    def fit(self, X, y=None):
        """
        This should fit classifier. All the "work" should be done here.
        """
        if (self.kernel == "linear"):
            self.k = linear_kernel
        elif (self.kernel == "RBF"):
            self.k = functools.partial(RBF_kernel, sigma=self.sigma)
        elif (self.kernel == "polynomial"):
            self.k = functools.partial(polynomial_kernel, offset=self.offset, degree=self.degree)
        else:
            raise ValueError('Unrecognized kernel type requested.')
        
        self.kernel_machine_ = train_soft_svm(X, y, self.k, self.max_epoch, self.l2reg)

        return self

    def predict(self, X, y=None):
        try:
            getattr(self, "kernel_machine_")
        except AttributeError:
            raise RuntimeError("You must train classifer before predicting data!")

        return(self.kernel_machine_.predict(X))

    def score(self, X, y=None):
        # get the average square error
        return(np.max(0,y*self.predict(X)).mean())

# %%
param_grid = [{'kernel': ['RBF'],'sigma':[0.01,0.03,0.1,0.3,1,3,10], 'l2reg': np.exp2(-np.arange(-5,5,1))},
              {'kernel':['polynomial'],'offset':[-1,0,1], 'degree':[2,3,4,5],'l2reg':[0.1,1,10] },
              {'kernel':['linear'],'l2reg': [10,1,.01]}]
kernel_svm_estimator = KernelSVM()
grid = GridSearchCV(kernel_svm_estimator, 
                    param_grid,
                    cv = predefined_split,
                    scoring = make_scorer(mean_squared_error,greater_is_better = False),
#                     n_jobs = -1  #should allow parallelism, but crashes Python on my machine
                   )
grid.fit(np.vstack((x_train,x_test)),np.vstack((y_train,y_test)))
# Out:
# GridSearchCV(cv=PredefinedSplit(test_fold=array([-1, -1, ...,  0,  0])),
#              error_score=nan,
#              estimator=KernelSVM(degree=2, kernel='RBF', l2reg=1,
#                                  max_epoch=5000, offset=1, sigma=1),
#              iid='deprecated', n_jobs=None,
#              param_grid=[{'kernel': ['RBF'],
#                           'l2reg': array([32.    , 16.    ,  8.    ,  4.    ,  2.    ,  1.    ,  0.5   ,
#         0.25  ,  0.125 ,  0.0625]),
#                           'sigma': [0.01, 0.03, 0.1, 0.3, 1, 3, 10]},
#                          {'degree': [2, 3, 4, 5], 'kernel': ['polynomial'],
#                           'l2reg': [0.1, 1, 10], 'offset': [-1, 0, 1]},
#                          {'kernel': ['linear'], 'l2reg': [10, 1, 0.01]}],
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=make_scorer(mean_squared_error, greater_is_better=False),
#              verbose=0)

# %%
pd.set_option('display.max_rows', 950)
df = pd.DataFrame(grid.cv_results_)
# Flip sign of score back, because GridSearchCV likes to maximize,
# so it flips the sign of the score if "greater_is_better=FALSE"
df['mean_test_score'] = -df['mean_test_score']
# df['mean_train_score'] = -df['mean_train_score']
cols_to_keep = ["param_kernel","param_l2reg" ,"param_offset","param_degree",
                "param_sigma","mean_test_score"]
df_toshow = df[cols_to_keep].fillna('-')
df_toshow.sort_values(by=["mean_test_score"])
# Out:
#     param_kernel  param_l2reg param_offset param_degree param_sigma  \
# 67           RBF       0.0625            -            -           1
# 60           RBF       0.1250            -            -           1
# 68           RBF       0.0625            -            -           3
# 77    polynomial      10.0000            0            2           -
# 76    polynomial      10.0000           -1            2           -
# 78    polynomial      10.0000            1            2           -
# 61           RBF       0.1250            -            -           3
# 53           RBF       0.2500            -            -           1
# 54           RBF       0.2500            -            -           3
# 47           RBF       0.5000            -            -           3
# 87    polynomial      10.0000            1            3           -
# 41           RBF       1.0000            -            -          10
# 46           RBF       0.5000            -            -           1
# 66           RBF       0.0625            -            -         0.3
# 48           RBF       0.5000            -            -          10
# 34           RBF       2.0000            -            -          10
# 55           RBF       0.2500            -            -          10
# 40           RBF       1.0000            -            -           3
# 86    polynomial      10.0000            0            3           -
# 62           RBF       0.1250            -            -          10
# 107       linear       1.0000            -            -           -
# 59           RBF       0.1250            -            -         0.3
# 39           RBF       1.0000            -            -           1
# 27           RBF       4.0000            -            -          10
# 33           RBF       2.0000            -            -           3
# 106       linear      10.0000            -            -           -
# 52           RBF       0.2500            -            -         0.3
# 32           RBF       2.0000            -            -           1
# 20           RBF       8.0000            -            -          10
# 26           RBF       4.0000            -            -           3
# 69           RBF       0.0625            -            -          10
# 45           RBF       0.5000            -            -         0.3
# 25           RBF       4.0000            -            -           1
# 13           RBF      16.0000            -            -          10
# 65           RBF       0.0625            -            -         0.1
# 19           RBF       8.0000            -            -           3
# 38           RBF       1.0000            -            -         0.3
# 18           RBF       8.0000            -            -           1
# 6            RBF      32.0000            -            -          10
# 58           RBF       0.1250            -            -         0.1
# 12           RBF      16.0000            -            -           3
# 31           RBF       2.0000            -            -         0.3
# 11           RBF      16.0000            -            -           1
# 51           RBF       0.2500            -            -         0.1
# 5            RBF      32.0000            -            -           3
# 24           RBF       4.0000            -            -         0.3
# 4            RBF      32.0000            -            -           1
# 44           RBF       0.5000            -            -         0.1
# 17           RBF       8.0000            -            -         0.3
# 37           RBF       1.0000            -            -         0.1
# 10           RBF      16.0000            -            -         0.3
# 30           RBF       2.0000            -            -         0.1
# 3            RBF      32.0000            -            -         0.3
# 23           RBF       4.0000            -            -         0.1
# 16           RBF       8.0000            -            -         0.1
# 9            RBF      16.0000            -            -         0.1
# 2            RBF      32.0000            -            -         0.1
# 0            RBF      32.0000            -            -        0.01
# 7            RBF      16.0000            -            -        0.01
# 1            RBF      32.0000            -            -        0.03
# 14           RBF       8.0000            -            -        0.01
# 8            RBF      16.0000            -            -        0.03
# 21           RBF       4.0000            -            -        0.01
# 15           RBF       8.0000            -            -        0.03
# 22           RBF       4.0000            -            -        0.03
# 28           RBF       2.0000            -            -        0.01
# 35           RBF       1.0000            -            -        0.01
# 29           RBF       2.0000            -            -        0.03
# 42           RBF       0.5000            -            -        0.01
# 36           RBF       1.0000            -            -        0.03
# 49           RBF       0.2500            -            -        0.01
# 43           RBF       0.5000            -            -        0.03
# 56           RBF       0.1250            -            -        0.01
# 63           RBF       0.0625            -            -        0.01
# 50           RBF       0.2500            -            -        0.03
# 57           RBF       0.1250            -            -        0.03
# 64           RBF       0.0625            -            -        0.03
# 108       linear       0.0100            -            -           -
# 83    polynomial       1.0000            0            3           -
# 74    polynomial       1.0000            0            2           -
# 75    polynomial       1.0000            1            2           -
# 71    polynomial       0.1000            0            2           -
# 84    polynomial       1.0000            1            3           -
# 72    polynomial       0.1000            1            2           -
# 73    polynomial       1.0000           -1            2           -
# 80    polynomial       0.1000            0            3           -
# 95    polynomial      10.0000            0            4           -
# 96    polynomial      10.0000            1            4           -
# 92    polynomial       1.0000            0            4           -
# 81    polynomial       0.1000            1            3           -
# 85    polynomial      10.0000           -1            3           -
# 93    polynomial       1.0000            1            4           -
# 70    polynomial       0.1000           -1            2           -
# 94    polynomial      10.0000           -1            4           -
# 104   polynomial      10.0000            0            5           -
# 105   polynomial      10.0000            1            5           -
# 90    polynomial       0.1000            1            4           -
# 82    polynomial       1.0000           -1            3           -
# 101   polynomial       1.0000            0            5           -
# 91    polynomial       1.0000           -1            4           -
# 89    polynomial       0.1000            0            4           -
# 102   polynomial       1.0000            1            5           -
# 79    polynomial       0.1000           -1            3           -
# 98    polynomial       0.1000            0            5           -
# 88    polynomial       0.1000           -1            4           -
# 99    polynomial       0.1000            1            5           -
# 103   polynomial      10.0000           -1            5           -
# 100   polynomial       1.0000           -1            5           -
# 97    polynomial       0.1000           -1            5           -
#
#      mean_test_score
# 67      6.543342e-01
# 60      8.308909e-01
# 68      8.386185e-01
# 77      9.418621e-01
# 76      9.668758e-01
# 78      9.748058e-01
# 61      1.024785e+00
# 53      1.043890e+00
# 54      1.075356e+00
# 47      1.158893e+00
# 87      1.179759e+00
# 41      1.183037e+00
# 46      1.201474e+00
# 66      1.214916e+00
# 48      1.214955e+00
# 34      1.249597e+00
# 55      1.254971e+00
# 40      1.255472e+00
# 86      1.256430e+00
# 62      1.263489e+00
# 107     1.275907e+00
# 59      1.288437e+00
# 39      1.292220e+00
# 27      1.305618e+00
# 33      1.319073e+00
# 106     1.328018e+00
# 52      1.339918e+00
# 32      1.341567e+00
# 20      1.344850e+00
# 26      1.350431e+00
# 69      1.351600e+00
# 45      1.364959e+00
# 25      1.366500e+00
# 13      1.370116e+00
# 65      1.372320e+00
# 19      1.372517e+00
# 38      1.378561e+00
# 18      1.379286e+00
# 6       1.381519e+00
# 58      1.381818e+00
# 12      1.381961e+00
# 31      1.385136e+00
# 11      1.385676e+00
# 51      1.386565e+00
# 5       1.387137e+00
# 24      1.388561e+00
# 4       1.388907e+00
# 44      1.388955e+00
# 17      1.390376e+00
# 37      1.390537e+00
# 10      1.391177e+00
# 30      1.391336e+00
# 3       1.391652e+00
# 23      1.391754e+00
# 16      1.391925e+00
# 9       1.391987e+00
# 2       1.392037e+00
# 0       1.392082e+00
# 7       1.392082e+00
# 1       1.392082e+00
# 14      1.392083e+00
# 8       1.392083e+00
# 21      1.392084e+00
# 15      1.392085e+00
# 22      1.392087e+00
# 28      1.392088e+00
# 35      1.392094e+00
# 29      1.392101e+00
# 42      1.392107e+00
# 36      1.392109e+00
# 49      1.392135e+00
# 43      1.392149e+00
# 56      1.392185e+00
# 63      1.392238e+00
# 50      1.392240e+00
# 57      1.392370e+00
# 64      1.392836e+00
# 108     1.659560e+00
# 83      1.988570e+00
# 74      2.521381e+00
# 75      2.860511e+00
# 71      4.067921e+00
# 84      4.127820e+00
# 72      7.759159e+00
# 73      1.287959e+01
# 80      2.219852e+01
# 95      6.981360e+01
# 96      1.007358e+02
# 92      1.024482e+02
# 81      1.065298e+02
# 85      3.109725e+02
# 93      1.329592e+03
# 70      1.465443e+03
# 94      3.173062e+03
# 104     6.135870e+03
# 105     1.333452e+04
# 90      2.062257e+04
# 82      2.994461e+04
# 101     6.410034e+04
# 91      7.934339e+04
# 89      7.556472e+05
# 102     1.878126e+06
# 79      2.928328e+06
# 98      5.561439e+06
# 88      3.945977e+07
# 99      8.843167e+07
# 103     3.539244e+08
# 100     1.895404e+10
# 97      1.017275e+12

# %%
# Code to help plot the decision regions
# (Note: This ode isn't necessarily entirely appropriate for the questions asked. So think about what you are doing.)
 
sigma = 1
max_epoch = 5000
l2reg = 0.0625
k = functools.partial(RBF_kernel, sigma=sigma)
f = train_soft_svm(x_train, y_train, k, max_epoch,l2reg)

#determine the decision regions for the predictions
x1_min = min(x_test[:,0])
x1_max= max(x_test[:,0])
x2_min = min(x_test[:,1])
x2_max= max(x_test[:,1])
h=0.1
xx, yy = np.meshgrid(np.arange(x1_min, x1_max, h),
                     np.arange(x2_min, x2_max, h))

Z = f.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

#determine the predictions for the test set
y_bar = f.predict (x_test) 
correct = np.multiply(y_bar.reshape(-1,1),y_test) > 0
#determine predictions for the training set
yplus = np.ma.masked_where(y_test[:,0]<=0, y_test[:,0])
yminus = np.ma.masked_where(y_test[:,0]>0, y_test[:,0])
xplus = x_test[~np.array(yplus.mask)]
xminus = x_test[~np.array(yminus.mask)]
correctplus = correct[~np.array(yplus.mask)]
correctminus = correct[~np.array(yminus.mask)]
color_dict = {True:'b',False:'r'}
color_plus = [color_dict[r] for r in correctplus.ravel()]
color_minus = [color_dict[r] for r in correctminus.ravel()]

#plot the learned boundary and the predictions for the test set
figsize = plt.figaspect(0.8)
f, (ax) = plt.subplots(1, 1, figsize=figsize) 
decision =ax.contourf(xx, yy, Z, cmap=plt.cm.coolwarm, alpha=0.8,vmin=-1,vmax=1)
pluses = ax.scatter (xplus[:,0], xplus[:,1], marker='+', c=color_plus, label = '+1 prediction for test set')
minuses = ax.scatter (xminus[:,0], xminus[:,1], marker=r'$-$', c=color_minus, label = '-1 prediction for test set')
ax.set_ylabel(r"$x_2$", fontsize=11)
ax.set_xlabel(r"$x_1$", fontsize=11)
ax.set_title('SVM with RBF Kernel: training set size = %s'% len(data_train), fontsize=9) 
ax.set_aspect('equal')
ax.axis('tight')
ax.legend(handles=[pluses, minuses], fontsize=9)
plt.colorbar(decision)
plt.show()
